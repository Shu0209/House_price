# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('bengaluru_house_prices.csv')

# %%
df.head(5)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df2=df.drop(['area_type','availability','society','balcony'],axis=1)

# %%
df2.shape
# Out:
# (13320, 5)

# %%
df2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df2['bath']=df2['bath'].fillna(df2['bath'].mean())

# %%
df2
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath           0
# price          0
# dtype: int64

# %%
df2=df2.dropna()

# %%
df2.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
df=df2

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df['room']=df['size'].apply(lambda x:int(x.split(' ')[0]))
# Out:
# C:\Users\bhand\AppData\Local\Temp\ipykernel_12760\3111194519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['room']=df['size'].apply(lambda x:int(x.split(' ')[0]))

# %%
df.head(5)
# Out:
#                    location       size total_sqft  bath   price  room
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07     2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00     4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00     3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00     3
# 4                  Kothanur      2 BHK       1200   2.0   51.00     2

# %%
df['room'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# room          0
# dtype: int64

# %%
df[df['room']>20]
# Out:
#                        location        size total_sqft  bath  price  room
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0    27
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0    43

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13303 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13303 non-null  object
#  1   size        13303 non-null  object
#  2   total_sqft  13303 non-null  object
#  3   bath        13303 non-null  float64
#  4   price       13303 non-null  float64
#  5   room        13303 non-null  int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 727.5+ KB

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
df2=df

# %%
def convert(x):
    try:
        if '-' in x:
            a, b = x.split('-')
            return (float(a) + float(b)) / 2
        else:
            return float(x)
    except:
        return None

# %%
df['total_sqft']=df['total_sqft'].apply(convert)
# Out:
# C:\Users\bhand\AppData\Local\Temp\ipykernel_12760\358267294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_sqft']=df['total_sqft'].apply(convert)

# %%
df['total_sqft']
# Out:
# 0        1056.0
# 1        2600.0
# 2        1440.0
# 3        1521.0
# 4        1200.0
#           ...
# 13315    3453.0
# 13316    3600.0
# 13317    1141.0
# 13318    4689.0
# 13319     550.0
# Name: total_sqft, Length: 13303, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13303 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13303 non-null  object
#  1   size        13303 non-null  object
#  2   total_sqft  13257 non-null  float64
#  3   bath        13303 non-null  float64
#  4   price       13303 non-null  float64
#  5   room        13303 non-null  int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 727.5+ KB

# %%
df=df.drop('size',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13303 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13303 non-null  object
#  1   total_sqft  13257 non-null  float64
#  2   bath        13303 non-null  float64
#  3   price       13303 non-null  float64
#  4   room        13303 non-null  int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 623.6+ KB

# %%
df.isnull().sum()
# Out:
# location       0
# total_sqft    46
# bath           0
# price          0
# room           0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# location      0
# total_sqft    0
# bath          0
# price         0
# room          0
# dtype: int64

# %%
df.head()
# Out:
#                    location  total_sqft  bath   price  room
# 0  Electronic City Phase II      1056.0   2.0   39.07     2
# 1          Chikka Tirupathi      2600.0   5.0  120.00     4
# 2               Uttarahalli      1440.0   2.0   62.00     3
# 3        Lingadheeranahalli      1521.0   3.0   95.00     3
# 4                  Kothanur      1200.0   2.0   51.00     2

# %%
df['price_sqft']=((df['price']/df['total_sqft'])*100000).astype(int)

# %%
df
# Out:
#                        location  total_sqft  bath   price  room  price_sqft
# 0      Electronic City Phase II      1056.0   2.0   39.07     2        3699
# 1              Chikka Tirupathi      2600.0   5.0  120.00     4        4615
# 2                   Uttarahalli      1440.0   2.0   62.00     3        4305
# 3            Lingadheeranahalli      1521.0   3.0   95.00     3        6245
# 4                      Kothanur      1200.0   2.0   51.00     2        4250
# ...                         ...         ...   ...     ...   ...         ...
# 13315                Whitefield      3453.0   4.0  231.00     5        6689
# 13316             Richards Town      3600.0   5.0  400.00     4       11111
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00     2        5258
# 13318           Padmanabhanagar      4689.0   4.0  488.00     4       10407
# 13319              Doddathoguru       550.0   1.0   17.00     1        3090
#
# [13257 rows x 6 columns]

# %%
df['location'].nunique()
# Out:
# 1298

# %%
x=(df['location'].value_counts())
type(x)
# Out:
# pandas.core.series.Series

# %%
location_less_than_10=x[x<=10]

# %%
location_less_than_10
# Out:
# location
# Ganga Nagar                  10
# Nagappa Reddy Layout         10
# Naganathapura                10
# Sadashiva Nagar              10
# Basapura                     10
#                              ..
# Indiranagar HAL 2nd Stage     1
# Maruthi HBCS Layout           1
# K R C kothanur                1
# 1Channasandra                 1
# Abshot Layout                 1
# Name: count, Length: 1058, dtype: int64

# %%
df['location']=df['location'].apply(lambda x:'other' if x in location_less_than_10 else x)

# %%
df.tail(5)
# Out:
#                     location  total_sqft  bath  price  room  price_sqft
# 13315             Whitefield      3453.0   4.0  231.0     5        6689
# 13316                  other      3600.0   5.0  400.0     4       11111
# 13317  Raja Rajeshwari Nagar      1141.0   2.0   60.0     2        5258
# 13318        Padmanabhanagar      4689.0   4.0  488.0     4       10407
# 13319           Doddathoguru       550.0   1.0   17.0     1        3090

# %%
df['location'].nunique()
# Out:
# 241

# %%
x=df['price']*100000
y=df['total_sqft']
plt.scatter(x,y)

# %%
sns.boxplot(x='price_sqft',data=df)
plt.show()

# %%
Q1=df['price_sqft'].quantile(0.25)
Q3=df['price_sqft'].quantile(0.75)

IQR=Q3-Q1

lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

df=df[(df['price_sqft']>=lower_fence) & (df['price_sqft']<=upper_fence)]

# %%
sns.boxplot(x='price_sqft',data=df)
plt.show()

# %%
df.shape
# Out:
# (11990, 6)

# %%
df.head(5)
# Out:
#                    location  total_sqft  bath   price  room  price_sqft
# 0  Electronic City Phase II      1056.0   2.0   39.07     2        3699
# 1          Chikka Tirupathi      2600.0   5.0  120.00     4        4615
# 2               Uttarahalli      1440.0   2.0   62.00     3        4305
# 3        Lingadheeranahalli      1521.0   3.0   95.00     3        6245
# 4                  Kothanur      1200.0   2.0   51.00     2        4250

# %%
sns.boxplot(x='room',data=df)
plt.show()

# %%
Q1=df['room'].quantile(0.25)
Q3=df['room'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

# %%
df=df[(df['room']>=lower_fence) & (df['room']<=upper_fence)]

# %%
df
# Out:
#                        location  total_sqft  bath   price  room  price_sqft
# 0      Electronic City Phase II      1056.0   2.0   39.07     2        3699
# 1              Chikka Tirupathi      2600.0   5.0  120.00     4        4615
# 2                   Uttarahalli      1440.0   2.0   62.00     3        4305
# 3            Lingadheeranahalli      1521.0   3.0   95.00     3        6245
# 4                      Kothanur      1200.0   2.0   51.00     2        4250
# ...                         ...         ...   ...     ...   ...         ...
# 13314         Green Glen Layout      1715.0   3.0  112.00     3        6530
# 13316                     other      3600.0   5.0  400.00     4       11111
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00     2        5258
# 13318           Padmanabhanagar      4689.0   4.0  488.00     4       10407
# 13319              Doddathoguru       550.0   1.0   17.00     1        3090
#
# [11543 rows x 6 columns]

# %%
df.shape
# Out:
# (11543, 6)

# %%
sns.boxplot(x='bath',data=df)
plt.show()

# %%
Q1=df['bath'].quantile(0.25)
Q3=df['bath'].quantile(0.75)

IQR=Q3-Q1

lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

df=df[(df['bath']>=lower_fence) & (df['bath']<=upper_fence)]

# %%
sns.boxplot(x='bath',data=df)
plt.show()

# %%
sns.boxplot(x='total_sqft',data=df)
plt.show()

# %%
Q1=df['total_sqft'].quantile(0.25)
Q3=df['total_sqft'].quantile(0.75)

IQR=Q3-Q1

lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

df=df[(df['total_sqft']>=lower_fence) & (df['total_sqft']<=upper_fence)]

# %%
sns.boxplot(x='total_sqft',data=df)
plt.show()

# %%
df.head(5)
# Out:
#                    location  total_sqft  bath  price  room  price_sqft
# 0  Electronic City Phase II      1056.0   2.0  39.07     2        3699
# 2               Uttarahalli      1440.0   2.0  62.00     3        4305
# 3        Lingadheeranahalli      1521.0   3.0  95.00     3        6245
# 4                  Kothanur      1200.0   2.0  51.00     2        4250
# 5                Whitefield      1170.0   2.0  38.00     2        3247

# %%
df.shape
# Out:
# (10541, 6)

# %%
sns.boxplot(x='price',data=df)
plt.show()

# %%
Q1=df['price'].quantile(0.25)
Q3=df['price'].quantile(0.75)

IQR=Q3-Q1

lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

df=df[(df['price']>=lower_fence) & (df['price']<=upper_fence)]

# %%
sns.boxplot(x='price',data=df)
plt.show()

# %%
df.shape
# Out:
# (10108, 6)

# %%
new_df=pd.get_dummies(df['location'])

# %%
df2=pd.concat([df,new_df],axis=1)

# %%
df2.head(5)
# Out:
#                    location  total_sqft  bath  price  room  price_sqft  \
# 0  Electronic City Phase II      1056.0   2.0  39.07     2        3699
# 2               Uttarahalli      1440.0   2.0  62.00     3        4305
# 3        Lingadheeranahalli      1521.0   3.0  95.00     3        6245
# 4                  Kothanur      1200.0   2.0  51.00     2        4250
# 5                Whitefield      1170.0   2.0  38.00     2        3247
#
#     Devarachikkanahalli  1st Block Jayanagar  1st Phase JP Nagar  \
# 0                 False                False               False
# 2                 False                False               False
# 3                 False                False               False
# 4                 False                False               False
# 5                 False                False               False
#
#    2nd Phase Judicial Layout  ...  Vishveshwarya Layout  Vishwapriya Layout  \
# ...

# %%
df2=df2.drop('other',axis=1)

# %%
df2.head(5)
# Out:
#                    location  total_sqft  bath  price  room  price_sqft  \
# 0  Electronic City Phase II      1056.0   2.0  39.07     2        3699
# 2               Uttarahalli      1440.0   2.0  62.00     3        4305
# 3        Lingadheeranahalli      1521.0   3.0  95.00     3        6245
# 4                  Kothanur      1200.0   2.0  51.00     2        4250
# 5                Whitefield      1170.0   2.0  38.00     2        3247
#
#     Devarachikkanahalli  1st Block Jayanagar  1st Phase JP Nagar  \
# 0                 False                False               False
# 2                 False                False               False
# 3                 False                False               False
# 4                 False                False               False
# 5                 False                False               False
#
#    2nd Phase Judicial Layout  ...  Vijayanagar  Vishveshwarya Layout  \
# 0                      False  ...        False                 False
# ...

# %%
df2.isnull().sum()
# Out:
# location              0
# total_sqft            0
# bath                  0
# price                 0
# room                  0
#                      ..
# Yelachenahalli        0
# Yelahanka             0
# Yelahanka New Town    0
# Yelenahalli           0
# Yeshwanthpur          0
# Length: 244, dtype: int64

# %%
df2=df2.drop('location',axis=1)

# %%
df2=df2.drop('price_sqft',axis=1)

# %%
df2.head(5)
# Out:
#    total_sqft  bath  price  room   Devarachikkanahalli  1st Block Jayanagar  \
# 0      1056.0   2.0  39.07     2                 False                False
# 2      1440.0   2.0  62.00     3                 False                False
# 3      1521.0   3.0  95.00     3                 False                False
# 4      1200.0   2.0  51.00     2                 False                False
# 5      1170.0   2.0  38.00     2                 False                False
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  5th Block Hbr Layout  \
# 0               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
# 5               False                      False                 False
#
#    5th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# ...

# %%
X=df2.drop('price',axis=1)
Y=df['price']

# %%
X
# Out:
#        total_sqft  bath  room   Devarachikkanahalli  1st Block Jayanagar  \
# 0          1056.0   2.0     2                 False                False
# 2          1440.0   2.0     3                 False                False
# 3          1521.0   3.0     3                 False                False
# 4          1200.0   2.0     2                 False                False
# 5          1170.0   2.0     2                 False                False
# ...           ...   ...   ...                   ...                  ...
# 13312      1262.0   2.0     2                 False                False
# 13313      1345.0   2.0     3                 False                False
# 13314      1715.0   3.0     3                 False                False
# 13317      1141.0   2.0     2                 False                False
# 13319       550.0   1.0     1                 False                False
#
#        1st Phase JP Nagar  2nd Phase Judicial Layout  5th Block Hbr Layout  \
# ...

# %%
Y
# Out:
# 0         39.07
# 2         62.00
# 3         95.00
# 4         51.00
# 5         38.00
#           ...
# 13312     47.00
# 13313     57.00
# 13314    112.00
# 13317     60.00
# 13319     17.00
# Name: price, Length: 10108, dtype: float64

# %%
#Using Train Test Split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,Y_test)
# Out:
# 0.6393890457740299

# %%
# Using k-fold Cross validation 
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv=ShuffleSplit(n_splits=4,test_size=0.2,random_state=0)

cross_val_score(LinearRegression(),X,Y,cv=cv)
# Out:
# array([0.63334821, 0.6315716 , 0.64870497, 0.64519779])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,Y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['squared_error','friedman_mse'],
                'splitter': ['best','random'],
                'max_depth': [5, 10, 15, None]
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=4, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,Y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,Y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.639706
# 1              lasso    0.532101
# 2      decision_tree    0.622000
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'max_depth': 15,...

# %%
def predict_price(location, sqft, bath, bhk):
    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = bhk

    if location in X.columns:
        loc_index = np.where(X.columns == location)[0][0]
        x[loc_index] = 1
    else:
        print(f"Warning: Location '{location}' not found. Prediction may be less accurate.")

    # Convert to DataFrame with same column names
    x_df = pd.DataFrame([x], columns=X.columns)

    return lr.predict(x_df)[0]

# %%
predict_price('Uttarahalli',1440.0, 2, 3)
# Out:
# 60.12239925576242

# %%
df.head(5)
# Out:
#                    location  total_sqft  bath  price  room  price_sqft
# 0  Electronic City Phase II      1056.0   2.0  39.07     2        3699
# 2               Uttarahalli      1440.0   2.0  62.00     3        4305
# 3        Lingadheeranahalli      1521.0   3.0  95.00     3        6245
# 4                  Kothanur      1200.0   2.0  51.00     2        4250
# 5                Whitefield      1170.0   2.0  38.00     2        3247

# %%
import pickle

pickle.dump(lr,open('house_price.pkl','wb'))
